# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x_train = np.load("/its/home/ts468/PhD/Intel-Neuromorphic-Research-Project/raw-spiking-heidleberg-digits-80input/training_x_spikes.npy", allow_pickle = True)

# %%
plt.scatter(x_train[0]['t'], x_train[0]['x'])
plt.ylim(0, 80)

plt.show()

# %%
import torch
import spikingjelly.datasets as sjds
import os

# %%
import tonic

SSC_dir = '/its/home/ts468/data/tonicSSC/'

d = tonic.datasets.SSC(SSC_dir)
e, t = d[0]

plt.figure(figsize=(8, 6), dpi = 1000)
plt.scatter(e['t']/1000000, e['x'], c = 'C0', s = 1)
plt.ylabel("input neuron")
plt.xlabel("timestep (s)")
plt.title("Spiking Speech Commands (SSC)")
plt.show()

# %%
import tonic

SHD_dir = '/its/home/ts468/data/tonicSHD/'

d = tonic.datasets.SHD(SHD_dir)
e, t = d[0]

plt.figure(figsize=(8, 6), dpi = 1000)
plt.scatter(e['t']/1000000, e['x'], c = 'C0', s = 1)
plt.ylabel("input neuron")
plt.xlabel("timestep (s)")
plt.title("Spiking Heidelberg Digits (SHD)")
plt.show()
