# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
path = "output/testing_3_updated_dataset/"
input_training_spikes_3 = np.load(path + "hidden_spike_counts_unfiltered.npy", allow_pickle = True)

spike_total_over_epoch_3 = []

for i in range(input_training_spikes_3.shape[1]):
    spike_total_over_epoch_3.append(np.sum(input_training_spikes_3[0][i]))

# %%
path = "output/testing_4_updated_dataset/"
input_training_spikes_4 = np.load(path + "hidden_spike_counts_unfiltered.npy", allow_pickle = True)

spike_total_over_epoch_4 = []

for i in range(input_training_spikes_4.shape[1]):
    spike_total_over_epoch_4.append(np.sum(input_training_spikes_4[0][i]))

# %%
plt.plot(spike_total_over_epoch_3)
#plt.xlim(37000, 39000)
plt.show()

# %%
plt.plot(spike_total_over_epoch_4)
#plt.xlim(37000, 39000)
plt.xlim(40000, 41000)
plt.show()

# %%
x = np.load("/its/home/ts468/PhD/Intel-Neuromorphic-Research-Project/spiking-google-speech-commands/testing_x_spikes.npy", allow_pickle=True)

# %%
x[5]
# Out:
# array([(46, 313, 1), (45, 315, 1), (47, 315, 1), (57, 318, 1),
#        (56, 319, 1), (58, 319, 1), (44, 320, 1), (48, 320, 1),
#        (49, 320, 1), (42, 321, 1), (43, 322, 1), (55, 322, 1),
#        (59, 322, 1), (60, 324, 1), (41, 326, 1), (54, 326, 1),
#        (50, 327, 1), (62, 327, 1), (63, 328, 1), (51, 329, 1),
#        (64, 329, 1), (53, 330, 1), (61, 330, 1), (52, 333, 1),
#        (39, 334, 1), (40, 334, 1), (67, 335, 1), (65, 337, 1),
#        (68, 337, 1), (73, 338, 1), (45, 341, 1), (46, 343, 1),
#        (69, 343, 1), (74, 344, 1), (44, 345, 1), (70, 346, 1),
#        (38, 347, 1), (47, 349, 1), (56, 350, 1), (49, 351, 1),
#        (66, 351, 1), (57, 352, 1), (58, 352, 1), (55, 353, 1),
#        (59, 353, 1), (43, 354, 1), (60, 355, 1), (72, 355, 1),
#        (41, 356, 1), (42, 356, 1), (48, 356, 1), (71, 356, 1),
#        (54, 357, 1), (37, 359, 1), (51, 359, 1), (50, 360, 1),
#        (53, 361, 1), (61, 361, 1), (62, 361, 1), (40, 364, 1),
# ...

# %%
path = "/its/home/ts468/PhD/Intel-Neuromorphic-Research-Project/output/clamped_weights_10/SC/"

# %%
i2h_weights = np.load(path + "18-Conn_Pop1_Pop2-g.npy", allow_pickle=True)

# %%
plt.plot(np.sort(i2h_weights.flatten()))
plt.show()

# %%
x = np.load("display/3000.npy", allow_pickle=True)

plt.plot(x)

# %%
a = []
b = []
c = []

# %%
{a: (-90.0, 90.0), b: ((-80.0, 80.0) if True else (-10.0, 10.0)), c: (-10.0, 10.0)}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 {a: (-90.0, 90.0), b: ((-80.0, 80.0) if True else (-10.0, 10.0)), c: (-10.0, 10.0)}
#
# TypeError: unhashable type: 'list'
